# %%
#input usia
print("=================USIA======================")
inputUsia = int(input("Masukkan usia anda: "))
print("===========================================")

#kondisi usia
if inputUsia >= 0 and inputUsia <= 12:
    print("\n Anda dikategorikan sebagai Anak-anak")
elif inputUsia >= 13 and inputUsia <= 17:
    print("\n Anda dikategorikan sebagai Remaja")
elif inputUsia >= 18 and inputUsia <= 59:
    print("\n Anda dikategorikan sebagai Dewasa")
elif inputUsia >= 60:
    print("\n Anda dikategorikan sebagai Lansia")
else:
    print("\nUsia tidak valid")
# Out:
# =================USIA======================
# Masukkan usia anda: 11
# ...
#
#  Anda dikategorikan sebagai Anak-anak
